# %% [markdown]
# # https://pbpython.com/styling-pandas.html

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data/2018_Sales_Total.xlsx')

# %%
df.head(5)
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                date
# 0       86.69    3380.91 2018-01-01 07:21:51
# 1       63.16     -63.16 2018-01-01 10:00:47
# 2       90.70    2086.10 2018-01-01 13:24:58
# 3       21.05     863.05 2018-01-01 15:05:22
# 4       83.21     499.26 2018-01-01 23:26:55

# %%
# quick summary to see how much the customers have purchased from us and what their average purchase amount looks like
df.groupby('name')['ext price'].agg(['mean', 'sum'])
# Out:
#                                         mean        sum
# name
# Barton LLC                       1334.615854  109438.50
# Cronin, Oberbrunner and Spencer  1339.321642   89734.55
# Frami, Hills and Schmidt         1438.466528  103569.59
# Fritsch, Russel and Anderson     1385.366790  112214.71
# Halvorson, Crona and Champlin    1206.971724   70004.36
# Herman LLC                       1336.532258   82865.00
# Jerde-Hilpert                    1265.072247  112591.43
# Kassulke, Ondricka and Metz      1350.797969   86451.07
# Keeling LLC                      1363.977027  100934.30
# Kiehn-Spinka                     1260.870506   99608.77
# Koepp Ltd                        1264.152927  103660.54
# Kuhn-Gusikowski                  1247.866849   91094.28
# Kulas Inc                        1461.191064  137351.96
# Pollich LLC                      1196.536712   87347.18
# Purdy-Kunde                      1469.777547   77898.21
# Sanford and Sons                 1391.872958   98822.98
# Stokes LLC                       1271.332222   91535.92
# Trantow-Barrows                  1312.567872  123381.38
# White-Trantow                    1579.558023  135841.99
# Will LLC                         1411.318919  104437.60

# %%
(df.groupby('name')['ext price'].agg(['mean', 'sum']).style.format('${0:,.2f}')) # style format https://mkaz.blog/code/python-string-format-cookbook/
# Out:
# <style type="text/css">
# </style>
# <table id="T_befc2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_befc2_level0_row0" class="row_heading level0 row0" >Barton LLC</th>
#       <td id="T_befc2_row0_col0" class="data row0 col0" >$1,334.62</td>
#       <td id="T_befc2_row0_col1" class="data row0 col1" >$109,438.50</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row1" class="row_heading level0 row1" >Cronin, Oberbrunner and Spencer</th>
#       <td id="T_befc2_row1_col0" class="data row1 col0" >$1,339.32</td>
#       <td id="T_befc2_row1_col1" class="data row1 col1" >$89,734.55</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row2" class="row_heading level0 row2" >Frami, Hills and Schmidt</th>
#       <td id="T_befc2_row2_col0" class="data row2 col0" >$1,438.47</td>
#       <td id="T_befc2_row2_col1" class="data row2 col1" >$103,569.59</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row3" class="row_heading level0 row3" >Fritsch, Russel and Anderson</th>
#       <td id="T_befc2_row3_col0" class="data row3 col0" >$1,385.37</td>
#       <td id="T_befc2_row3_col1" class="data row3 col1" >$112,214.71</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row4" class="row_heading level0 row4" >Halvorson, Crona and Champlin</th>
#       <td id="T_befc2_row4_col0" class="data row4 col0" >$1,206.97</td>
#       <td id="T_befc2_row4_col1" class="data row4 col1" >$70,004.36</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row5" class="row_heading level0 row5" >Herman LLC</th>
#       <td id="T_befc2_row5_col0" class="data row5 col0" >$1,336.53</td>
#       <td id="T_befc2_row5_col1" class="data row5 col1" >$82,865.00</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row6" class="row_heading level0 row6" >Jerde-Hilpert</th>
#       <td id="T_befc2_row6_col0" class="data row6 col0" >$1,265.07</td>
#       <td id="T_befc2_row6_col1" class="data row6 col1" >$112,591.43</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row7" class="row_heading level0 row7" >Kassulke, Ondricka and Metz</th>
#       <td id="T_befc2_row7_col0" class="data row7 col0" >$1,350.80</td>
#       <td id="T_befc2_row7_col1" class="data row7 col1" >$86,451.07</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row8" class="row_heading level0 row8" >Keeling LLC</th>
#       <td id="T_befc2_row8_col0" class="data row8 col0" >$1,363.98</td>
#       <td id="T_befc2_row8_col1" class="data row8 col1" >$100,934.30</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row9" class="row_heading level0 row9" >Kiehn-Spinka</th>
#       <td id="T_befc2_row9_col0" class="data row9 col0" >$1,260.87</td>
#       <td id="T_befc2_row9_col1" class="data row9 col1" >$99,608.77</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row10" class="row_heading level0 row10" >Koepp Ltd</th>
#       <td id="T_befc2_row10_col0" class="data row10 col0" >$1,264.15</td>
#       <td id="T_befc2_row10_col1" class="data row10 col1" >$103,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row11" class="row_heading level0 row11" >Kuhn-Gusikowski</th>
#       <td id="T_befc2_row11_col0" class="data row11 col0" >$1,247.87</td>
#       <td id="T_befc2_row11_col1" class="data row11 col1" >$91,094.28</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row12" class="row_heading level0 row12" >Kulas Inc</th>
#       <td id="T_befc2_row12_col0" class="data row12 col0" >$1,461.19</td>
#       <td id="T_befc2_row12_col1" class="data row12 col1" >$137,351.96</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row13" class="row_heading level0 row13" >Pollich LLC</th>
#       <td id="T_befc2_row13_col0" class="data row13 col0" >$1,196.54</td>
#       <td id="T_befc2_row13_col1" class="data row13 col1" >$87,347.18</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row14" class="row_heading level0 row14" >Purdy-Kunde</th>
#       <td id="T_befc2_row14_col0" class="data row14 col0" >$1,469.78</td>
#       <td id="T_befc2_row14_col1" class="data row14 col1" >$77,898.21</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row15" class="row_heading level0 row15" >Sanford and Sons</th>
#       <td id="T_befc2_row15_col0" class="data row15 col0" >$1,391.87</td>
#       <td id="T_befc2_row15_col1" class="data row15 col1" >$98,822.98</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row16" class="row_heading level0 row16" >Stokes LLC</th>
#       <td id="T_befc2_row16_col0" class="data row16 col0" >$1,271.33</td>
#       <td id="T_befc2_row16_col1" class="data row16 col1" >$91,535.92</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row17" class="row_heading level0 row17" >Trantow-Barrows</th>
#       <td id="T_befc2_row17_col0" class="data row17 col0" >$1,312.57</td>
#       <td id="T_befc2_row17_col1" class="data row17 col1" >$123,381.38</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row18" class="row_heading level0 row18" >White-Trantow</th>
#       <td id="T_befc2_row18_col0" class="data row18 col0" >$1,579.56</td>
#       <td id="T_befc2_row18_col1" class="data row18 col1" >$135,841.99</td>
#     </tr>
#     <tr>
#       <th id="T_befc2_level0_row19" class="row_heading level0 row19" >Will LLC</th>
#       <td id="T_befc2_row19_col0" class="data row19 col0" >$1,411.32</td>
#       <td id="T_befc2_row19_col1" class="data row19 col1" >$104,437.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
#  look at total sales by each month
monthly_sales = df.groupby([pd.Grouper(key='date', freq='M')])['ext price'].agg(['sum']).reset_index()
monthly_sales['pct_of_total'] = monthly_sales['sum'] / df['ext price'].sum()
print(monthly_sales)
# Out:
#          date        sum  pct_of_total
# 0  2018-01-31  185361.66      0.091818
# 1  2018-02-28  146211.62      0.072426
# 2  2018-03-31  203921.38      0.101012
# 3  2018-04-30  174574.11      0.086475
# 4  2018-05-31  165418.55      0.081940
# 5  2018-06-30  174089.33      0.086235
# 6  2018-07-31  191662.11      0.094939
# 7  2018-08-31  153778.59      0.076174
# 8  2018-09-30  168443.17      0.083438
# 9  2018-10-31  171495.32      0.084950
# 10 2018-11-30  119961.22      0.059423
# 11 2018-12-31  163867.26      0.081171

# %%
# use a dictionary to define a unique formatting string for each column
format_dict = {'sum':'${0:,.0f}', 'date': '{:%m-%Y}', 'pct_of_total': '{:.2%}'}
monthly_sales.style.format(format_dict).hide_index() # hide_index function suppresses the display of the index
# Out:
# <style type="text/css">
# </style>
# <table id="T_4099f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >sum</th>
#       <th class="col_heading level0 col2" >pct_of_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4099f_row0_col0" class="data row0 col0" >01-2018</td>
#       <td id="T_4099f_row0_col1" class="data row0 col1" >$185,362</td>
#       <td id="T_4099f_row0_col2" class="data row0 col2" >9.18%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row1_col0" class="data row1 col0" >02-2018</td>
#       <td id="T_4099f_row1_col1" class="data row1 col1" >$146,212</td>
#       <td id="T_4099f_row1_col2" class="data row1 col2" >7.24%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row2_col0" class="data row2 col0" >03-2018</td>
#       <td id="T_4099f_row2_col1" class="data row2 col1" >$203,921</td>
#       <td id="T_4099f_row2_col2" class="data row2 col2" >10.10%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row3_col0" class="data row3 col0" >04-2018</td>
#       <td id="T_4099f_row3_col1" class="data row3 col1" >$174,574</td>
#       <td id="T_4099f_row3_col2" class="data row3 col2" >8.65%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row4_col0" class="data row4 col0" >05-2018</td>
#       <td id="T_4099f_row4_col1" class="data row4 col1" >$165,419</td>
#       <td id="T_4099f_row4_col2" class="data row4 col2" >8.19%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row5_col0" class="data row5 col0" >06-2018</td>
#       <td id="T_4099f_row5_col1" class="data row5 col1" >$174,089</td>
#       <td id="T_4099f_row5_col2" class="data row5 col2" >8.62%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row6_col0" class="data row6 col0" >07-2018</td>
#       <td id="T_4099f_row6_col1" class="data row6 col1" >$191,662</td>
#       <td id="T_4099f_row6_col2" class="data row6 col2" >9.49%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row7_col0" class="data row7 col0" >08-2018</td>
#       <td id="T_4099f_row7_col1" class="data row7 col1" >$153,779</td>
#       <td id="T_4099f_row7_col2" class="data row7 col2" >7.62%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row8_col0" class="data row8 col0" >09-2018</td>
#       <td id="T_4099f_row8_col1" class="data row8 col1" >$168,443</td>
#       <td id="T_4099f_row8_col2" class="data row8 col2" >8.34%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row9_col0" class="data row9 col0" >10-2018</td>
#       <td id="T_4099f_row9_col1" class="data row9 col1" >$171,495</td>
#       <td id="T_4099f_row9_col2" class="data row9 col2" >8.49%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row10_col0" class="data row10 col0" >11-2018</td>
#       <td id="T_4099f_row10_col1" class="data row10 col1" >$119,961</td>
#       <td id="T_4099f_row10_col2" class="data row10 col2" >5.94%</td>
#     </tr>
#     <tr>
#       <td id="T_4099f_row11_col0" class="data row11 col0" >12-2018</td>
#       <td id="T_4099f_row11_col1" class="data row11 col1" >$163,867</td>
#       <td id="T_4099f_row11_col2" class="data row11 col2" >8.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# highlight the highest number in green and the lowest number in color Trinidad (#cd4f39)
(monthly_sales
 .style
 .format(format_dict)
 .hide_index()
 .highlight_max(subset=['sum','pct_of_total'],color='lightgreen')
 .highlight_min(subset=['sum','pct_of_total'],color='#cd4f39'))
# Out:
# <style type="text/css">
# #T_99d94_row2_col1, #T_99d94_row2_col2 {
#   background-color: lightgreen;
# }
# #T_99d94_row10_col1, #T_99d94_row10_col2 {
#   background-color: #cd4f39;
# }
# </style>
# <table id="T_99d94_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >sum</th>
#       <th class="col_heading level0 col2" >pct_of_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99d94_row0_col0" class="data row0 col0" >01-2018</td>
#       <td id="T_99d94_row0_col1" class="data row0 col1" >$185,362</td>
#       <td id="T_99d94_row0_col2" class="data row0 col2" >9.18%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row1_col0" class="data row1 col0" >02-2018</td>
#       <td id="T_99d94_row1_col1" class="data row1 col1" >$146,212</td>
#       <td id="T_99d94_row1_col2" class="data row1 col2" >7.24%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row2_col0" class="data row2 col0" >03-2018</td>
#       <td id="T_99d94_row2_col1" class="data row2 col1" >$203,921</td>
#       <td id="T_99d94_row2_col2" class="data row2 col2" >10.10%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row3_col0" class="data row3 col0" >04-2018</td>
#       <td id="T_99d94_row3_col1" class="data row3 col1" >$174,574</td>
#       <td id="T_99d94_row3_col2" class="data row3 col2" >8.65%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row4_col0" class="data row4 col0" >05-2018</td>
#       <td id="T_99d94_row4_col1" class="data row4 col1" >$165,419</td>
#       <td id="T_99d94_row4_col2" class="data row4 col2" >8.19%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row5_col0" class="data row5 col0" >06-2018</td>
#       <td id="T_99d94_row5_col1" class="data row5 col1" >$174,089</td>
#       <td id="T_99d94_row5_col2" class="data row5 col2" >8.62%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row6_col0" class="data row6 col0" >07-2018</td>
#       <td id="T_99d94_row6_col1" class="data row6 col1" >$191,662</td>
#       <td id="T_99d94_row6_col2" class="data row6 col2" >9.49%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row7_col0" class="data row7 col0" >08-2018</td>
#       <td id="T_99d94_row7_col1" class="data row7 col1" >$153,779</td>
#       <td id="T_99d94_row7_col2" class="data row7 col2" >7.62%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row8_col0" class="data row8 col0" >09-2018</td>
#       <td id="T_99d94_row8_col1" class="data row8 col1" >$168,443</td>
#       <td id="T_99d94_row8_col2" class="data row8 col2" >8.34%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row9_col0" class="data row9 col0" >10-2018</td>
#       <td id="T_99d94_row9_col1" class="data row9 col1" >$171,495</td>
#       <td id="T_99d94_row9_col2" class="data row9 col2" >8.49%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row10_col0" class="data row10 col0" >11-2018</td>
#       <td id="T_99d94_row10_col1" class="data row10 col1" >$119,961</td>
#       <td id="T_99d94_row10_col2" class="data row10 col2" >5.94%</td>
#     </tr>
#     <tr>
#       <td id="T_99d94_row11_col0" class="data row11 col0" >12-2018</td>
#       <td id="T_99d94_row11_col1" class="data row11 col1" >$163,867</td>
#       <td id="T_99d94_row11_col2" class="data row11 col2" >8.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# background_gradient can highlight the range of values in a column
(monthly_sales.style
 .format(format_dict)
 .background_gradient(subset=['sum'], cmap='BuGn')) # https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <style type="text/css">
# #T_a6fcd_row0_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_a6fcd_row1_col1 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_a6fcd_row2_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a6fcd_row3_col1 {
#   background-color: #3ba76c;
#   color: #f1f1f1;
# }
# #T_a6fcd_row4_col1 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_a6fcd_row5_col1 {
#   background-color: #3ca86d;
#   color: #f1f1f1;
# }
# #T_a6fcd_row6_col1 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_a6fcd_row7_col1 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_a6fcd_row8_col1 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_a6fcd_row9_col1 {
#   background-color: #44af79;
#   color: #f1f1f1;
# }
# #T_a6fcd_row10_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a6fcd_row11_col1 {
#   background-color: #60bf9c;
#   color: #000000;
# }
# </style>
# <table id="T_a6fcd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >sum</th>
#       <th class="col_heading level0 col2" >pct_of_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6fcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6fcd_row0_col0" class="data row0 col0" >01-2018</td>
#       <td id="T_a6fcd_row0_col1" class="data row0 col1" >$185,362</td>
#       <td id="T_a6fcd_row0_col2" class="data row0 col2" >9.18%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6fcd_row1_col0" class="data row1 col0" >02-2018</td>
#       <td id="T_a6fcd_row1_col1" class="data row1 col1" >$146,212</td>
#       <td id="T_a6fcd_row1_col2" class="data row1 col2" >7.24%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6fcd_row2_col0" class="data row2 col0" >03-2018</td>
#       <td id="T_a6fcd_row2_col1" class="data row2 col1" >$203,921</td>
#       <td id="T_a6fcd_row2_col2" class="data row2 col2" >10.10%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6fcd_row3_col0" class="data row3 col0" >04-2018</td>
#       <td id="T_a6fcd_row3_col1" class="data row3 col1" >$174,574</td>
#       <td id="T_a6fcd_row3_col2" class="data row3 col2" >8.65%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6fcd_row4_col0" class="data row4 col0" >05-2018</td>
#       <td id="T_a6fcd_row4_col1" class="data row4 col1" >$165,419</td>
#       <td id="T_a6fcd_row4_col2" class="data row4 col2" >8.19%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6fcd_row5_col0" class="data row5 col0" >06-2018</td>
#       <td id="T_a6fcd_row5_col1" class="data row5 col1" >$174,089</td>
#       <td id="T_a6fcd_row5_col2" class="data row5 col2" >8.62%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6fcd_row6_col0" class="data row6 col0" >07-2018</td>
#       <td id="T_a6fcd_row6_col1" class="data row6 col1" >$191,662</td>
#       <td id="T_a6fcd_row6_col2" class="data row6 col2" >9.49%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6fcd_row7_col0" class="data row7 col0" >08-2018</td>
#       <td id="T_a6fcd_row7_col1" class="data row7 col1" >$153,779</td>
#       <td id="T_a6fcd_row7_col2" class="data row7 col2" >7.62%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6fcd_row8_col0" class="data row8 col0" >09-2018</td>
#       <td id="T_a6fcd_row8_col1" class="data row8 col1" >$168,443</td>
#       <td id="T_a6fcd_row8_col2" class="data row8 col2" >8.34%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6fcd_row9_col0" class="data row9 col0" >10-2018</td>
#       <td id="T_a6fcd_row9_col1" class="data row9 col1" >$171,495</td>
#       <td id="T_a6fcd_row9_col2" class="data row9 col2" >8.49%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a6fcd_row10_col0" class="data row10 col0" >11-2018</td>
#       <td id="T_a6fcd_row10_col1" class="data row10 col1" >$119,961</td>
#       <td id="T_a6fcd_row10_col2" class="data row10 col2" >5.94%</td>
#     </tr>
#     <tr>
#       <th id="T_a6fcd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a6fcd_row11_col0" class="data row11 col0" >12-2018</td>
#       <td id="T_a6fcd_row11_col1" class="data row11 col1" >$163,867</td>
#       <td id="T_a6fcd_row11_col2" class="data row11 col2" >8.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# drawing bar charts within the columns
(monthly_sales
 .style
 .format(format_dict)
 .hide_index()
 .bar(color='#FFA07A', vmin=100_000, subset=['sum'], align='zero')
 .bar(color='lightgreen', vmin=0, subset=['pct_of_total'], align='zero')
 .set_caption('2018 Sales Performance'))
# Out:
# <style type="text/css">
# #T_60320_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 95.4%, transparent 95.4%);
# }
# #T_60320_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 95.4%, transparent 95.4%);
# }
# #T_60320_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 85.8%, transparent 85.8%);
# }
# #T_60320_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 85.8%, transparent 85.8%);
# }
# #T_60320_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 100.0%, transparent 100.0%);
# }
# #T_60320_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_60320_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.8%, transparent 92.8%);
# }
# #T_60320_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.8%, transparent 92.8%);
# }
# #T_60320_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 90.6%, transparent 90.6%);
# }
# #T_60320_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.6%, transparent 90.6%);
# }
# #T_60320_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.7%, transparent 92.7%);
# }
# #T_60320_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.7%, transparent 92.7%);
# }
# #T_60320_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 97.0%, transparent 97.0%);
# }
# #T_60320_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 97.0%, transparent 97.0%);
# }
# #T_60320_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 87.7%, transparent 87.7%);
# }
# #T_60320_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.7%, transparent 87.7%);
# }
# #T_60320_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 91.3%, transparent 91.3%);
# }
# #T_60320_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 91.3%, transparent 91.3%);
# }
# #T_60320_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.0%, transparent 92.0%);
# }
# #T_60320_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.0%, transparent 92.0%);
# }
# #T_60320_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 79.4%, transparent 79.4%);
# }
# #T_60320_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 79.4%, transparent 79.4%);
# }
# #T_60320_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 90.2%, transparent 90.2%);
# }
# #T_60320_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.2%, transparent 90.2%);
# }
# </style>
# <table id="T_60320_">
#   <caption>2018 Sales Performance</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >sum</th>
#       <th class="col_heading level0 col2" >pct_of_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_60320_row0_col0" class="data row0 col0" >01-2018</td>
#       <td id="T_60320_row0_col1" class="data row0 col1" >$185,362</td>
#       <td id="T_60320_row0_col2" class="data row0 col2" >9.18%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row1_col0" class="data row1 col0" >02-2018</td>
#       <td id="T_60320_row1_col1" class="data row1 col1" >$146,212</td>
#       <td id="T_60320_row1_col2" class="data row1 col2" >7.24%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row2_col0" class="data row2 col0" >03-2018</td>
#       <td id="T_60320_row2_col1" class="data row2 col1" >$203,921</td>
#       <td id="T_60320_row2_col2" class="data row2 col2" >10.10%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row3_col0" class="data row3 col0" >04-2018</td>
#       <td id="T_60320_row3_col1" class="data row3 col1" >$174,574</td>
#       <td id="T_60320_row3_col2" class="data row3 col2" >8.65%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row4_col0" class="data row4 col0" >05-2018</td>
#       <td id="T_60320_row4_col1" class="data row4 col1" >$165,419</td>
#       <td id="T_60320_row4_col2" class="data row4 col2" >8.19%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row5_col0" class="data row5 col0" >06-2018</td>
#       <td id="T_60320_row5_col1" class="data row5 col1" >$174,089</td>
#       <td id="T_60320_row5_col2" class="data row5 col2" >8.62%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row6_col0" class="data row6 col0" >07-2018</td>
#       <td id="T_60320_row6_col1" class="data row6 col1" >$191,662</td>
#       <td id="T_60320_row6_col2" class="data row6 col2" >9.49%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row7_col0" class="data row7 col0" >08-2018</td>
#       <td id="T_60320_row7_col1" class="data row7 col1" >$153,779</td>
#       <td id="T_60320_row7_col2" class="data row7 col2" >7.62%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row8_col0" class="data row8 col0" >09-2018</td>
#       <td id="T_60320_row8_col1" class="data row8 col1" >$168,443</td>
#       <td id="T_60320_row8_col2" class="data row8 col2" >8.34%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row9_col0" class="data row9 col0" >10-2018</td>
#       <td id="T_60320_row9_col1" class="data row9 col1" >$171,495</td>
#       <td id="T_60320_row9_col2" class="data row9 col2" >8.49%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row10_col0" class="data row10 col0" >11-2018</td>
#       <td id="T_60320_row10_col1" class="data row10 col1" >$119,961</td>
#       <td id="T_60320_row10_col2" class="data row10 col2" >5.94%</td>
#     </tr>
#     <tr>
#       <td id="T_60320_row11_col0" class="data row11 col0" >12-2018</td>
#       <td id="T_60320_row11_col1" class="data row11 col1" >$163,867</td>
#       <td id="T_60320_row11_col2" class="data row11 col2" >8.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sparklines

def sparkline_str(x):
    bins=np.histogram(x)[0]
    sl = ''.join(sparklines(bins))
    return sl
sparkline_str.__name__ = "sparkline"

# %%
df.groupby('name')['quantity', 'ext price'].agg(['mean', sparkline_str])
# Out:
# /var/folders/3r/gzbp9xfx0612n9bv_qj8rkqw0000gn/T/ipykernel_41951/3732561847.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('name')['quantity', 'ext price'].agg(['mean', sparkline_str])
# /usr/local/Caskroom/miniconda/base/envs/mach_lern/lib/python3.9/site-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3r/gzbp9xfx0612n9bv_qj8rkqw0000gn/T/ipykernel_41951/3732561847.py in <module>
# ----> 1 df.groupby('name')['quantity', 'ext price'].agg(['mean', sparkline_str])
#
# /usr/local/Caskroom/miniconda/base/envs/mach_lern/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# /usr/local/Caskroom/miniconda/base/envs/mach_lern/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
# --> 164             return self.agg_list_like()
#     165
#     166         if callable(arg):
#
# /usr/local/Caskroom/miniconda/base/envs/mach_lern/lib/python3.9/site-packages/pandas/core/apply.py in agg_list_like(self)
#     377         # if we are empty
#     378         if not len(results):
# --> 379             raise ValueError("no results")
#     380
#     381         try:
#
# ValueError: no results
